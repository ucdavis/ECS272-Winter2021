# %%
import numpy as np
import csv
import json

import os
os.chdir('..')

# %%
def make_json(csvFilePath, jsonFilePath, key_str):
     
    # create a dictionary
    data = {}
     
    # Open a csv reader called DictReader
    with open(csvFilePath, encoding='utf-8') as csvf:
        csvReader = csv.DictReader(csvf)
         
        # Convert each row into a dictionary 
        # and add it to data
        for rows in csvReader:
             
            # Assuming a column named 'No' to
            # be the primary key
            key = rows[key_str]
            data[key] = rows
 
    # Open a json writer, and use the json.dumps() 
    # function to dump data
    with open(jsonFilePath, 'w', encoding='utf-8') as jsonf:
        jsonf.write(json.dumps(data, indent=4))

# %%
# Driver Code
 
# Decide the two file paths according to your 
# computer system
# csvFilePath = r'Names.csv'
# jsonFilePath = r'Names.json'
# path_root = '/Users/maryam/Documents/Courses/Courses_UCDavis/Winter2021/InfoViz_ECS272_WQ2021/Homeworks/GithubRepo/ECS272-Winter2021/Homework2/datasets/'
path_root = '/Users/maryam/Documents/Courses/Courses_UCDavis/Winter2021/InfoViz_ECS272_WQ2021/Homeworks/GithubRepo/ECS272-Winter2021/Homework2/Templates/es6-webpack-template/node/src/assets/data'
path_datasets = path_root + '/spotify_data/'
csvFilePath = path_datasets + r'data_by_year.csv'
jsonFilePath = path_datasets + r'data_by_year.json'

key_str = 'year'

# Call the make_json function
make_json(csvFilePath, jsonFilePath, key_str)

# %%
csvFilePath = path_datasets + r'data.csv'
jsonFilePath = path_datasets + r'data.json'

 
# Call the make_json function
make_json(csvFilePath, jsonFilePath, key_str)

# %%
csvFilePath = path_datasets + r'data_by_genres.csv'
jsonFilePath = path_datasets + r'data_by_genres.json'

key_str = 'genres'
# Call the make_json function
make_json(csvFilePath, jsonFilePath, key_str)

# %%
csvFilePath = path_datasets + r'data_w_genres.csv'
jsonFilePath = path_datasets + r'data_w_genres.json'

 
# Call the make_json function
make_json(csvFilePath, jsonFilePath, key_str)

# %%
csvFilePath = path_datasets + r'data_by_artist.csv'
jsonFilePath = path_datasets + r'data_by_artist.json'

key_str = 'artists'
# Call the make_json function
make_json(csvFilePath, jsonFilePath, key_str)

# %%
import pandas as pd

path_root = '/Users/maryam/Documents/Courses/Courses_UCDavis/Winter2021/InfoViz_ECS272_WQ2021/Homeworks/GithubRepo/ECS272-Winter2021/Homework2/Templates/es6-webpack-template/node/src/assets/data'
path_datasets = path_root + '/spotify_data/'
csvFilePath = path_datasets + r'data_by_year.csv'

data_by_year = pd.read_csv(csvFilePath)

# %%
dby = data_by_year
dby
# Out:
#     mode  year  acousticness  danceability    duration_ms    energy  \
# 0      1  1921      0.886896      0.418597  260537.166667  0.231815
# 1      1  1922      0.938592      0.482042  165469.746479  0.237815
# 2      1  1923      0.957247      0.577341  177942.362162  0.262406
# 3      1  1924      0.940200      0.549894  191046.707627  0.344347
# 4      1  1925      0.962607      0.573863  184986.924460  0.278594
# ..   ...   ...           ...           ...            ...       ...
# 95     1  2016      0.284171      0.600202  221396.510295  0.592855
# 96     1  2017      0.286099      0.612217  211115.696787  0.590421
# 97     1  2018      0.267633      0.663500  206001.007133  0.602435
# 98     1  2019      0.278299      0.644814  201024.788096  0.593224
# 99     1  2020      0.219931      0.692904  193728.397537  0.631232
#
#     instrumentalness  liveness   loudness  speechiness       tempo   valence  \
# ...

# %%
dby['year']
# Out:
# 0     1921
# 1     1922
# 2     1923
# 3     1924
# 4     1925
#       ...
# 95    2016
# 96    2017
# 97    2018
# 98    2019
# 99    2020
# Name: year, Length: 100, dtype: int64

# %%
from scipy.stats import pearsonr
import numpy as np
import csv

feat_corr = []

path_root = '/Users/maryam/Documents/Courses/Courses_UCDavis/Winter2021/InfoViz_ECS272_WQ2021/Homeworks/GithubRepo/ECS272-Winter2021/Homework2/Templates/es6-webpack-template/node/src/assets/data'
path_datasets = path_root + '/spotify_data/'
csvFilePath = path_datasets + r'data_by_year_corr.csv'


dimensions = ['danceability', 'energy','speechiness','liveness']

# dimensions = ['danceability']
with open(csvFilePath, mode='w', newline='') as feat_corr_csv:
    fieldnames = ['groups', 'variables','r']
    
    writer = csv.DictWriter(feat_corr_csv, fieldnames = fieldnames)
    writer.writeheader()
    for i in dimensions:
        for j in dimensions:
            print(i,j,'\n')
            vec1 = dby[i]
            vec2 = dby[j]
            r, p_val = pearsonr(vec1, vec2)
            feat_corr.append([i,j,np.str(r)])
#             writer.writerow([i,j,np.str(r)])
            writer.writerow({'groups' : i,'variables': j, 'r': r})
# Out:
# danceability danceability
#
# danceability energy
#
# danceability speechiness
#
# danceability liveness
#
# energy danceability
#
# energy energy
#
# energy speechiness
#
# energy liveness
#
# speechiness danceability
#
# speechiness energy
#
# speechiness speechiness
#
# speechiness liveness
#
# liveness danceability
#
# liveness energy
#
# liveness speechiness
#
# liveness liveness

# %%
feat_corr
# Out:
# [['danceability', 'danceability', '1.0'],
#  ['danceability', 'energy', '0.5382920179247498'],
#  ['danceability', 'speechiness', '0.2666288727382278'],
#  ['danceability', 'liveness', '-0.3846530965531086'],
#  ['energy', 'danceability', '0.5382920179247498'],
#  ['energy', 'energy', '1.0'],
#  ['energy', 'speechiness', '-0.42085430050847406'],
#  ['energy', 'liveness', '-0.5005402451111509'],
#  ['speechiness', 'danceability', '0.2666288727382278'],
#  ['speechiness', 'energy', '-0.42085430050847406'],
#  ['speechiness', 'speechiness', '1.0'],
#  ['speechiness', 'liveness', '0.3329202932630916'],
#  ['liveness', 'danceability', '-0.3846530965531086'],
#  ['liveness', 'energy', '-0.5005402451111509'],
#  ['liveness', 'speechiness', '0.3329202932630916'],
#  ['liveness', 'liveness', '1.0']]

# %%
# Out:
# danceability danceability 0
#
# danceability energy 0
#
# danceability speechiness 0
#
# danceability liveness 0
#
# danceability acousticness 0
#
# danceability valence 0
#
# danceability tempo 0
#
# danceability instrumentalness 0
#
# energy danceability 1
#
# energy energy 1
#
# energy speechiness 1
#
# energy liveness 1
#
# energy acousticness 1
#
# energy valence 1
#
# energy tempo 1
#
# energy instrumentalness 1
#
# speechiness danceability 2
#
# speechiness energy 2
#
# speechiness speechiness 2
#
# speechiness liveness 2
#
# speechiness acousticness 2
#
# speechiness valence 2
#
# speechiness tempo 2
#
# speechiness instrumentalness 2
#
# liveness danceability 3
#
# liveness energy 3
#
# liveness speechiness 3
#
# liveness liveness 3
#
# liveness acousticness 3
#
# liveness valence 3
#
# liveness tempo 3
#
# liveness instrumentalness 3
#
# acousticness danceability 4
#
# acousticness energy 4
#
# acousticness speechiness 4
#
# acousticness liveness 4
#
# ...

# %%
dbc
# Out:
#       mode                  genres  acousticness  danceability   duration_ms  \
# 0        1  21st century classical      0.979333      0.162883  1.602977e+05
# 1        1                   432hz      0.494780      0.299333  1.048887e+06
# 2        1                   8-bit      0.762000      0.712000  1.151770e+05
# 3        1                      []      0.651417      0.529093  2.328809e+05
# 4        1              a cappella      0.676557      0.538961  1.906285e+05
# ...    ...                     ...           ...           ...           ...
# 2968     1                    zolo      0.222625      0.547082  2.580991e+05
# 2969     0                 zouglou      0.161000      0.863000  2.063200e+05
# 2970     1                    zouk      0.263261      0.748889  3.060728e+05
# 2971     0            zurich indie      0.993000      0.705667  1.984173e+05
# 2972     1                  zydeco      0.421038      0.629409  1.716717e+05
#
# ...

# %%
import pandas as pd

path_root = '/Users/maryam/Documents/Courses/Courses_UCDavis/Winter2021/InfoViz_ECS272_WQ2021/Homeworks/GithubRepo/ECS272-Winter2021/Homework2/Templates/es6-webpack-template/node/src/assets/data'
path_datasets = path_root + '/spotify_data/'

csvFilePath = path_datasets + r'data_by_genres.csv'
data_by_genres = pd.read_csv(csvFilePath)
dbg = data_by_genres

csvFilePath = path_datasets + r'data_by_artist.csv'
data_by_artist = pd.read_csv(csvFilePath)
dba = data_by_artist

csvFilePath = path_datasets + r'data_by_year.csv'
data_by_year = pd.read_csv(csvFilePath)
dby = data_by_year

# %%
def NormalizeData(data):
    return (data - np.min(data)) / (np.max(data) - np.min(data))

# %%
import matplotlib.pyplot as plt

selected_d = dbg['popularity']
dbg['normalized_popularity'] = NormalizeData(selected_d)

csvFilePath = path_datasets + r'data_by_genres_updated.csv'
dbg.to_csv(csvFilePath)

# %%
import matplotlib.pyplot as plt

selected_d = dba['popularity']
dba['normalized_popularity'] = NormalizeData(selected_d)

csvFilePath = path_datasets + r'data_by_artist_updated.csv'
dba.to_csv(csvFilePath)

# %%
import matplotlib.pyplot as plt

selected_d = dby['popularity']
dby['normalized_popularity'] = NormalizeData(selected_d)

selected_d = dby['tempo']
dby['normalized_tempo'] = NormalizeData(selected_d)

selected_d = dby['duration_ms']
dby['normalized_duration_ms'] = NormalizeData(selected_d)

csvFilePath = path_datasets + r'data_by_year_updated.csv'
dby.to_csv(csvFilePath)

# %%
# dby['normalized_duration_ms']

# %% [markdown]
# # normalize data again

# %%
from scipy.stats import pearsonr
import numpy as np
import csv

csvFilePath = path_datasets + r'data_by_year.csv'
data_by_corr = pd.read_csv(csvFilePath)
dby = data_by_genres

feat_corr = []

path_root = '/Users/maryam/Documents/Courses/Courses_UCDavis/Winter2021/InfoViz_ECS272_WQ2021/Homeworks/GithubRepo/ECS272-Winter2021/Homework2/Templates/es6-webpack-template/node/src/assets/data'
path_datasets = path_root + '/spotify_data/'
csvFilePath = path_datasets + r'data_by_year_more_corr.csv'


dimensions = ['danceability', 'energy','speechiness','liveness', 'acousticness', 'valence', 'normalized_tempo','instrumentalness','normalized_duration_ms']
dim_names = ['dance.', 'energy','speech.','live.', 'acoust.', 'valence', 'ntempo', 'instru.','ndur.']
# dimensions = ['danceability']
with open(csvFilePath, mode='w', newline='') as feat_corr_csv:
    fieldnames = ['groups', 'variables','r']
    
    writer = csv.DictWriter(feat_corr_csv, fieldnames = fieldnames)
    writer.writeheader()
    for indi,i in enumerate(dimensions):
        for indj,j in enumerate(dimensions):
            print(i,j,indi,'\n')
            vec1 = dby[i]
            vec2 = dby[j]
            r, p_val = pearsonr(vec1, vec2)
            feat_corr.append([dim_names[indi],dim_names[indj],np.str(r)])
#             writer.writerow([i,j,np.str(r)])
            writer.writerow({'groups' : dim_names[indi],'variables': dim_names[indj], 'r': r})
# Out:
# danceability danceability 0
#
# danceability energy 0
#
# danceability speechiness 0
#
# danceability liveness 0
#
# danceability acousticness 0
#
# danceability valence 0
#
# danceability normalized_tempo 0
#
# danceability instrumentalness 0
#
# danceability normalized_duration_ms 0
#
# energy danceability 1
#
# energy energy 1
#
# energy speechiness 1
#
# energy liveness 1
#
# energy acousticness 1
#
# energy valence 1
#
# energy normalized_tempo 1
#
# energy instrumentalness 1
#
# energy normalized_duration_ms 1
#
# speechiness danceability 2
#
# speechiness energy 2
#
# speechiness speechiness 2
#
# speechiness liveness 2
#
# speechiness acousticness 2
#
# speechiness valence 2
#
# speechiness normalized_tempo 2
#
# speechiness instrumentalness 2
#
# speechiness normalized_duration_ms 2
#
# liveness danceability 3
#
# liveness energy 3
#
# liveness speechiness 3
#
# liveness liveness 3
#
# liveness acousticness 3
#
# liveness valence 3
#
# liveness normalized_tempo 3
#
# ...

# %%
csvFilePath = path_datasets + r'data_by_year_more_corr.csv'
data_by_corr = pd.read_csv(csvFilePath)
dbc = data_by_genres

# %% [markdown]
# # try to select some genres from some years only

# %%
import pandas as pd

path_root = '/Users/maryam/Documents/Courses/Courses_UCDavis/Winter2021/InfoViz_ECS272_WQ2021/Homeworks/GithubRepo/ECS272-Winter2021/Homework2/Templates/es6-webpack-template/node/src/assets/data'
path_datasets = path_root + '/spotify_data/'
csvFilePath = path_datasets + r'data.csv'

data = pd.read_csv(csvFilePath)

# %%
data
# Out:
#         valence  year  acousticness  \
# 0        0.0594  1921       0.98200
# 1        0.9630  1921       0.73200
# 2        0.0394  1921       0.96100
# 3        0.1650  1921       0.96700
# 4        0.2530  1921       0.95700
# ...         ...   ...           ...
# 170648   0.6080  2020       0.08460
# 170649   0.7340  2020       0.20600
# 170650   0.6370  2020       0.10100
# 170651   0.1950  2020       0.00998
# 170652   0.6420  2020       0.13200
#
#                                                   artists  danceability  \
# 0       ['Sergei Rachmaninoff', 'James Levine', 'Berli...         0.279
# 1                                          ['Dennis Day']         0.819
# 2       ['KHP Kridhamardawa Karaton Ngayogyakarta Hadi...         0.328
# 3                                        ['Frank Parker']         0.275
# 4                                          ['Phil Regan']         0.418
# ...                                                   ...           ...
# ...

# %%
dy = data['year']

# %%
dy1 = data[dy==1921]
dy1
# Out:
#      valence  year  acousticness  \
# 0     0.0594  1921         0.982
# 1     0.9630  1921         0.732
# 2     0.0394  1921         0.961
# 3     0.1650  1921         0.967
# 4     0.2530  1921         0.957
# ..       ...   ...           ...
# 145   0.6580  1921         0.993
# 146   0.6890  1921         0.995
# 147   0.5340  1921         0.995
# 148   0.6590  1921         0.996
# 149   0.5120  1921         0.984
#
#                                                artists  danceability  \
# 0    ['Sergei Rachmaninoff', 'James Levine', 'Berli...         0.279
# 1                                       ['Dennis Day']         0.819
# 2    ['KHP Kridhamardawa Karaton Ngayogyakarta Hadi...         0.328
# 3                                     ['Frank Parker']         0.275
# 4                                       ['Phil Regan']         0.418
# ..                                                 ...           ...
# 145              ['Georges Bizet', 'Arturo Toscanini']         0.528
# ...

# %%
dy1

# %%
import pandas as pd

path_root = '/Users/maryam/Documents/Courses/Courses_UCDavis/Winter2021/InfoViz_ECS272_WQ2021/Homeworks/GithubRepo/ECS272-Winter2021/Homework2/Templates/es6-webpack-template/node/src/assets/data'
path_datasets = path_root + '/spotify_data/'

csvFilePath = path_datasets + r'data_by_genres_updated.csv'
data_by_genres = pd.read_csv(csvFilePath)
dbg = data_by_genres

csvFilePath = path_datasets + r'data_by_artist_updated.csv'
data_by_artist = pd.read_csv(csvFilePath)
dba = data_by_artist

csvFilePath = path_datasets + r'data_by_year_updated.csv'
data_by_year = pd.read_csv(csvFilePath)
dby = data_by_year

# %%
dbg
# Out:
#       Unnamed: 0  mode                  genres  acousticness  danceability  \
# 0              0     1  21st century classical      0.979333      0.162883
# 1              1     1                   432hz      0.494780      0.299333
# 2              2     1                   8-bit      0.762000      0.712000
# 3              3     1                      []      0.651417      0.529093
# 4              4     1              a cappella      0.676557      0.538961
# ...          ...   ...                     ...           ...           ...
# 2968        2968     1                    zolo      0.222625      0.547082
# 2969        2969     0                 zouglou      0.161000      0.863000
# 2970        2970     1                    zouk      0.263261      0.748889
# 2971        2971     0            zurich indie      0.993000      0.705667
# 2972        2972     1                  zydeco      0.421038      0.629409
#
# ...

# %%
top_pop = dbg['average_popularity']

# %%
import numpy as np
np.sort(top_pop)
# Out:
# array([0.        , 0.        , 0.        , ..., 0.99173554, 0.99173554,
#        1.        ])
